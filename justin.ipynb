# %%
print 'hello world'
# Out:
# hello world

# %%
2*30
# Out:
# 60

# %%
print 'hello world' *129
# Out:
# hello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello worldhello wo
# ...

# %%
x = 'computer'

# %%
print x
# Out:
# computer

# %%
print x * 4
# Out:
# computercomputercomputercomputer

# %%
print x * 100000
# Out:
# ...

# %%
justinslist = ['likefood', 'sleep', x]
print justinslist
# Out:
# ['likefood', 'sleep', 'computer']
